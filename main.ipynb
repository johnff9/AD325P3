# %%
# Out:
# Tree built from CSV successfully.
#
# All Patient Records (Initial):
# All Patient Records (Inorder Traversal):
# Patient ID: 1, Name: Peter Parker, Age: 35, Diagnosis: Flu, BP: 120/80, Pulse: 70, Temperature: 37.0
# Patient ID: 3, Name: Clint Barton, Age: 45, Diagnosis: Hypertension, BP: 140/90, Pulse: 80, Temperature: 36.9
# Patient ID: 5, Name: Tony Stark, Age: 60, Diagnosis: Arthritis, BP: 125/78, Pulse: 72, Temperature: 36.7
# Patient ID: 6, Name: Natasha Romanoff, Age: 32, Diagnosis: Cold, BP: 115/75, Pulse: 68, Temperature: 37.1
# Patient ID: 7, Name: Scott Lang, Age: 47, Diagnosis: Cancer, BP: 135/88, Pulse: 77, Temperature: 37.0
# Patient ID: 8, Name: Drax, Age: 55, Diagnosis: Heart Disease, BP: 145/92, Pulse: 82, Temperature: 36.8
# Patient ID: 9, Name: Wade Wilson, Age: 40, Diagnosis: Flu, BP: 120/80, Pulse: 70, Temperature: 36.9
# Patient ID: 10, Name: Professor X, Age: 29, Diagnosis: Pneumonia, BP: 130/85, Pulse: 75, Temperature: 37.3
# ...
